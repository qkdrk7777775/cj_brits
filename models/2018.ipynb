# %%
import torch 
import numpy as np 
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from sklearn import metrics

# %%
def standardization(X):
    std=np.apply_along_axis(np.nanstd,0,X)
    mean=np.apply_along_axis(np.nanmean,0,X)
    z=(X-mean)/std
    return [z,mean,std]

# %%
class MyDataset(Dataset):
    """ 
    자료 로드 부분 입력
    - forward
      - deltas
      - masks
      - values
    
    - backward
      - deltas
      - masks
      - values
      
    """ 
    def __init__(self):
        super(MyDataset,self).__init__()
        
        df=pd.read_csv('../NA_30per_QC2_gamak1 (1).csv',parse_dates=True,na_values='NaN')
        df['date']=pd.to_datetime(df['date'])

        #full date generate
        df=df.set_index('date')

        #year
        df=df[:'2019-01-01']
        df=df['2018-01-01':]
        temp=standardization(df)
        df=temp[0]
        self.mean_sd=temp[1],temp[2]
        #dt_range = pd.date_range(min(df.index), max(df.index), freq='1H')
        #na_date=set(dt_range)-set(df.index)
        #df=pd.concat([df ,pd.DataFrame(columns=df.columns,index=na_date)],axis=0)
        df=df.sort_index()
        self.df=df
        df_temp=df.copy()
        df_temp=df_temp.fillna(method='ffill')
        self.df_forwards=df_temp
        
        #forward
        dic=dict()
        for var in df.columns.values.tolist():
            print(var)
            temp=list()
            temp.append(0)
            for i in range(1,df.shape[0]):
                temp_df=df[[var]][i:i+1]
                if temp_df.notnull().values!=True:
                    temp.append(i-temp[-1])
                else:
                    temp.append(temp[-1])
            dic.update({var:temp})
        
        self.deltas=np.array(pd.DataFrame(dic))
        #eval generate
        df_temp=df.copy()
        for seed in range(1,df.shape[1]):
            np.random.seed(seed)
            temp_idx=np.random.choice(df.shape[0],int(np.ceil(df.shape[0]*.1)))
            df_temp[df_temp.columns[seed]][temp_idx]=np.nan
        self.eval=df_temp
        
        #backward
        df=df[::-1]
        self.b_df=df
        df_temp=df.copy()
        df_temp=df_temp.fillna(method='ffill')
        self.b_df_forwards=df_temp
        dic=dict()
        for var in df.columns.values.tolist():
            print(var)
            temp=list()
            temp.append(0)
            for i in range(1,df.shape[0]):
                temp_df=df[[var]][i:i+1]
                if temp_df.notnull().values!=True:
                    temp.append(-(i-temp[-1]))
                else:
                    temp.append(temp[-1])
            dic.update({var:temp})
        self.back_deltas=np.array(pd.DataFrame(dic))

        #eval generate
        df_temp=df.copy()
        for seed in range(1,df.shape[1]):
            np.random.seed(seed)
            temp_idx=np.random.choice(df.shape[0],int(np.ceil(df.shape[0]*.1)))
            df_temp[df_temp.columns[seed]][temp_idx]=np.nan
        self.b_eval=df_temp

        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if idx>=50:
            
            data=dict()
            data['forward']={'values':np.array(self.df)[(idx-50):(idx)],'masks':np.array(self.df.notnull()+0)[(idx-50):(idx)],
                             'deltas':self.deltas[idx:(idx+50)],'forwards':np.array(self.df_forwards)[(idx-50):(idx)],
                             'evals':np.array(self.eval)[(idx-50):(idx)],'eval_masks':np.array(self.eval.notnull()+0)[(idx-50):(idx)]}

            data['backward']={'values':np.array(self.b_df)[(idx-50):(idx)],'masks':np.array(self.b_df.notnull()+0)[(idx-50):(idx)],
                              'deltas':self.back_deltas[(idx-50):(idx)],'forwards':np.array(self.b_df_forwards)[(idx-50):(idx)],
                             'evals':np.array(self.b_eval)[(idx-50):(idx)],'eval_masks':np.array(self.b_eval.notnull()+0)[(idx-50):(idx)]}
            return data

# %%
def collate_fn(recs):
    if recs[0]!=None:
        if all(list(map(lambda x: x!=None,recs))):
            forward  = list(map(lambda x: x['forward'], recs))
            backward = list(map(lambda x: x['backward'], recs))
            if all(list(map(lambda x:len(x['deltas'])==50,forward))):
                def to_tensor_dict(recs):
                    values     =torch.FloatTensor(list(map(lambda r:r['values'],recs)))
                    masks      =torch.FloatTensor(list(map(lambda r:r['masks'], recs)))
                    deltas     =torch.FloatTensor(list(map(lambda r:r['deltas'],recs)))
                    evals      =torch.FloatTensor(list(map(lambda r:r['evals'], recs)))
                    eval_masks =torch.FloatTensor(list(map(lambda r:r['eval_masks'], recs)))

                    return {'values':values, 'masks': masks, 'deltas': deltas, 'evals': evals, 'eval_masks': eval_masks} 

                ret_dict = {'forward': to_tensor_dict(forward), 'backward': to_tensor_dict(backward)}
                return ret_dict

# %%
Mydata=MyDataset()
# Out:
# depth_top
# depth_middle
# depth_bottom
# wtemp_top
# wtemp_middle
# wtemp_bottom
# sal_top
# sal_middle
# sal_bottom
# do_top
# do_middle
# do_bottom
# density_top
# density_middle
# density_bottom
# dense_diff0
# dense_diff1
# depth_top
# depth_middle
# depth_bottom
# wtemp_top
# wtemp_middle
# wtemp_bottom
# sal_top
# sal_middle
# sal_bottom
# do_top
# do_middle
# do_bottom
# density_top
# density_middle
# density_bottom
# dense_diff0
# dense_diff1

# %%
from torch.autograd import Variable
def to_var(var):
    if torch.is_tensor(var):
        var = Variable(var)
        if torch.cuda.is_available():
            var = var.cuda()
        return var
    if isinstance(var, int) or isinstance(var, float) or isinstance(var, str):
        return var
    if isinstance(var, dict):
        for key in var:
            var[key] = to_var(var[key])
        return var
    if isinstance(var, list):
        var = map(lambda x: to_var(x), var)
        return var

# %%
import os 
#os.chdir('/home/ducj2/data/do_bottom/models')
os.chdir('../')
import models
import utils
import sys
sys.path.append('./models')
from models import brits_i

# %%
data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=False)

# %%
def evaluate(model, val_iter):
    model.eval()

    labels = []
    preds = []

    evals = []
    imputations = []

    save_impute = []
    save_label = []

    for idx, data in enumerate(val_iter):
        if data!=None:
            data = to_var(data)
            ret = model.run_on_batch(data, None)

            # save the imputation results which is used to test the improvement of traditional methods with imputed values
            save_impute.append(ret['imputations'].data.cpu().numpy())

            pred = ret['predictions'].data.cpu().numpy()

            eval_masks = ret['eval_masks'].data.cpu().numpy()
            eval_ = ret['evals'].data.cpu().numpy()
            imputation = ret['imputations'].data.cpu().numpy()

            evals += eval_[np.where(eval_masks == 1)].tolist()
            imputations += imputation[np.where(eval_masks == 1)].tolist()

            # collect test label & prediction
            pred = pred
            preds += pred.tolist()
    preds = np.asarray(preds)
#    print('AUC {}'.format(metrics.roc_auc_score(labels, preds)))

    evals = np.asarray(evals)
    imputations = np.asarray(imputations)

    print('MAE', np.abs(evals - imputations).mean())
    print('MRE', np.abs(evals - imputations).sum() / np.abs(evals).sum())
    save_impute = np.concatenate(save_impute, axis=0)
    np.save('./result_2018/{}_data'.format('brits_i'), save_impute)

# %%
#model = getattr(models, args.model).Model(108, 0.3, 1)
model= brits_i.Model()
if torch.cuda.is_available():
    model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=True)
for epoch in range(1000):
    model.train()
    run_loss = 0.0
    for idx, data in enumerate(data_iter):
        if data!=None:
            data = to_var(data)
            ret = model.run_on_batch(data, optimizer)
            run_loss += ret['loss'].item()
            print ('\r Progress epoch {}, {:.2f}%, average loss {}'.format(epoch, (idx + 1) * 100.0 / len(data_iter), run_loss / (idx + 1.0)))
    data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=False)
    evaluate(model, data_iter)
# Out:
#  Progress epoch 0, 0.66%, average loss 75.28227233886719
#  Progress epoch 0, 3.31%, average loss 30.494963073730467
#  Progress epoch 0, 3.97%, average loss 38.569803873697914
#  Progress epoch 0, 5.30%, average loss 38.2337064743042
#  Progress epoch 0, 5.96%, average loss 42.35043165418837
#  Progress epoch 0, 7.28%, average loss 41.345606023615055
#  Progress epoch 0, 8.61%, average loss 41.007459787222054
#  Progress epoch 0, 9.27%, average loss 43.628321511404856
#  Progress epoch 0, 10.60%, average loss 42.94490671157837
#  Progress epoch 0, 11.26%, average loss 44.84088718189913
#  Progress epoch 0, 12.58%, average loss 44.13326986212479
#  Progress epoch 0, 13.25%, average loss 45.76909637451172
#  Progress epoch 0, 15.89%, average loss 41.09439945220947
#  Progress epoch 0, 18.54%, average loss 37.86007499694824
#  Progress epoch 0, 19.21%, average loss 39.21824751229122
#  Progress epoch 0, 20.53%, average loss 39.117344025642645
#  Progress epoch 0, 21.19%, average loss 40.08032560348511
#  Progress epoch 0, 24.50%, average loss 36.643805632720124
#  Progress epoch 0, 25.83%, average loss 36.58819306202424
#  Progress epoch 0, 27.81%, average loss 35.69028745378767
#  Progress epoch 0, 28.48%, average loss 36.513926129008446
#  Progress epoch 0, 29.80%, average loss 36.49000498453776
#  Progress epoch 0, 31.79%, average loss 35.67195749282837
#  Progress epoch 0, 32.45%, average loss 36.37320584666972
#  Progress epoch 0, 34.44%, average loss 35.639721356905426
#  Progress epoch 0, 35.10%, average loss 36.266647194916345
#  Progress epoch 0, 35.76%, average loss 36.85460069444444
#  Progress epoch 0, 36.42%, average loss 37.38801311146129
#  Progress epoch 0, 37.75%, average loss 37.31666150009423
#  Progress epoch 0, 39.07%, average loss 37.21649169921875
#  Progress epoch 0, 39.74%, average loss 37.699353281656904
#  Progress epoch 0, 42.38%, average loss 36.39504420757294
#  Progress epoch 0, 43.05%, average loss 36.86146439772386
#  Progress epoch 0, 44.37%, average loss 36.83509097882171
#  Progress epoch 0, 45.03%, average loss 37.18638218150419
#  Progress epoch 9, 92.05%, average loss 27.7518304852273
#  Progress epoch 9, 92.72%, average loss 27.696390921728952
#  Progress epoch 9, 93.38%, average loss 27.621649444525968
#  Progress epoch 9, 94.04%, average loss 27.54780682711534
#  Progress epoch 9, 94.70%, average loss 27.474536395573114
#  Progress epoch 9, 95.36%, average loss 27.40690924723943
#  Progress epoch 9, 96.03%, average loss 27.3485960532879
#  Progress epoch 9, 96.69%, average loss 27.30590409448702
#  Progress epoch 9, 97.35%, average loss 27.26614217044545
#  Progress epoch 9, 98.01%, average loss 27.241984451139295
# MAE 0.4597744029211919
# MRE 0.6063592744035059
#  Progress epoch 10, 1.99%, average loss 11.09945297241211
#  Progress epoch 10, 2.65%, average loss 16.11120891571045
#  Progress epoch 10, 3.31%, average loss 18.7388671875
#  Progress epoch 10, 3.97%, average loss 20.024675369262695
#  Progress epoch 10, 4.64%, average loss 20.440728051321848
#  Progress epoch 10, 5.30%, average loss 20.413344860076904
#  Progress epoch 10, 5.96%, average loss 20.277043448554146
#  Progress epoch 10, 6.62%, average loss 20.13927936553955
#  Progress epoch 10, 7.28%, average loss 20.00838886607777
#  Progress epoch 10, 7.95%, average loss 19.879782994588215
#  Progress epoch 10, 8.61%, average loss 19.894419009868916
#  Progress epoch 10, 9.27%, average loss 20.05079827989851
#  Progress epoch 10, 9.93%, average loss 20.50720100402832
#  Progress epoch 10, 10.60%, average loss 21.029067158699036
#  Progress epoch 10, 11.26%, average loss 21.411574868594897
#  Progress epoch 10, 11.92%, average loss 21.5945946375529
#  Progress epoch 10, 12.58%, average loss 21.665243751124333
#  Progress epoch 10, 13.25%, average loss 21.788346576690675
#  Progress epoch 10, 13.91%, average loss 22.1879152570452
#  Progress epoch 10, 14.57%, average loss 22.528592803261496
#  Progress epoch 10, 15.23%, average loss 22.84621164073115
#  Progress epoch 10, 15.89%, average loss 23.15527319908142
#  Progress epoch 10, 16.56%, average loss 23.31135986328125
#  Progress epoch 10, 17.22%, average loss 23.398374043978176
#  Progress epoch 10, 17.88%, average loss 23.46870337592231
#  Progress epoch 10, 18.54%, average loss 23.529796532222203
#  Progress epoch 10, 19.21%, average loss 23.50275263293036
#  Progress epoch 10, 19.87%, average loss 23.368196741739908
#  Progress epoch 10, 20.53%, average loss 23.3758611986714
#  Progress epoch 10, 21.19%, average loss 23.707086980342865
#  Progress epoch 10, 21.85%, average loss 24.150278322624438
#  Progress epoch 10, 22.52%, average loss 24.516436128055346
#  Progress epoch 10, 23.18%, average loss 24.740449142456054
#  Progress epoch 10, 23.84%, average loss 24.998516665564644
#  Progress epoch 10, 24.50%, average loss 25.15708964579814
#  Progress epoch 10, 25.17%, average loss 25.220215948004473
#  Progress epoch 10, 25.83%, average loss 25.34158696883764
#  Progress epoch 10, 26.49%, average loss 25.474627208709716
#  Progress epoch 10, 27.15%, average loss 25.733836383354372
#  Progress epoch 10, 27.81%, average loss 26.038754145304363
#  Progress epoch 10, 28.48%, average loss 26.402275529018667
#  Progress epoch 10, 29.14%, average loss 26.475527373227205
#  Progress epoch 10, 29.80%, average loss 26.361395517985027
#  Progress epoch 10, 30.46%, average loss 26.21862088079038
#  Progress epoch 10, 31.13%, average loss 26.25321599270435
#  Progress epoch 10, 31.79%, average loss 26.391093293825787
#  Progress epoch 10, 32.45%, average loss 26.33440251253089
#  Progress epoch 10, 33.11%, average loss 26.0993479347229
#  Progress epoch 10, 33.77%, average loss 25.969743485544242
#  Progress epoch 10, 34.44%, average loss 25.99080887207618
#  Progress epoch 10, 35.10%, average loss 26.01489410760268
#  Progress epoch 10, 35.76%, average loss 26.0385187820152
#  Progress epoch 10, 36.42%, average loss 26.142123846574265
#  Progress epoch 10, 37.09%, average loss 26.161327617509023
#  Progress epoch 10, 37.75%, average loss 26.15014392451236
#  Progress epoch 10, 38.41%, average loss 26.17855876067589
#  Progress epoch 10, 39.07%, average loss 26.226146811145846
#  Progress epoch 10, 39.74%, average loss 26.324472920099893
#  Progress epoch 10, 40.40%, average loss 26.437943927577283
#  Progress epoch 10, 41.06%, average loss 26.498465061187744
#  Progress epoch 10, 41.72%, average loss 26.496172450837634
#  Progress epoch 10, 42.38%, average loss 26.476430609822273
#  Progress epoch 10, 43.05%, average loss 26.46356317079984
#  Progress epoch 10, 43.71%, average loss 26.424594806902338
#  Progress epoch 10, 44.37%, average loss 26.390109802359966
#  Progress epoch 10, 45.03%, average loss 26.422678428537704
#  Progress epoch 10, 45.70%, average loss 26.445389885833297
#  Progress epoch 10, 46.36%, average loss 26.437168516431537
#  Progress epoch 10, 47.02%, average loss 26.422249176132848
#  Progress epoch 10, 47.68%, average loss 26.407621264457703
#  Progress epoch 10, 48.34%, average loss 26.359771009993878
#  Progress epoch 10, 49.01%, average loss 26.32446169208836
#  Progress epoch 10, 49.67%, average loss 26.275288988749185
#  Progress epoch 10, 50.33%, average loss 26.215980190979806
#  Progress epoch 10, 50.99%, average loss 26.171708676722144
#  Progress epoch 10, 51.66%, average loss 26.150717600797996
#  Progress epoch 10, 52.32%, average loss 26.111730466915084
#  Progress epoch 10, 52.98%, average loss 26.08888441324234
#  Progress epoch 10, 53.64%, average loss 26.103672816429608
#  Progress epoch 10, 54.30%, average loss 26.10927578298057
#  Progress epoch 10, 54.97%, average loss 26.148382428180742
#  Progress epoch 10, 55.63%, average loss 26.221212375731696
#  Progress epoch 10, 56.29%, average loss 26.28357421650606
#  Progress epoch 10, 56.95%, average loss 26.261413762735767
#  Progress epoch 10, 57.62%, average loss 26.240273431799878
#  Progress epoch 10, 58.28%, average loss 26.23058755831285
#  Progress epoch 10, 58.94%, average loss 26.21989411986276
#  Progress epoch 10, 59.60%, average loss 26.218307865990532
#  Progress epoch 10, 60.26%, average loss 26.280935465634524
#  Progress epoch 10, 60.93%, average loss 26.36765910231549
#  Progress epoch 10, 61.59%, average loss 26.4425695173202
#  Progress epoch 10, 62.25%, average loss 26.477393403966378
#  Progress epoch 10, 62.91%, average loss 26.49122331518876
#  Progress epoch 10, 63.58%, average loss 26.480574935674667
#  Progress epoch 10, 64.24%, average loss 26.472160309860385
#  Progress epoch 10, 64.90%, average loss 26.499165758794668
#  Progress epoch 10, 65.56%, average loss 26.48418622065072
#  Progress epoch 10, 66.23%, average loss 26.462329607009888
#  Progress epoch 10, 66.89%, average loss 26.440066847470728
#  Progress epoch 10, 67.55%, average loss 26.34830275703879
#  Progress epoch 10, 68.21%, average loss 26.232129948810467
#  Progress epoch 10, 68.87%, average loss 26.234827142495377
#  Progress epoch 10, 69.54%, average loss 26.307925805591402
#  Progress epoch 10, 70.20%, average loss 26.321012811840706
#  Progress epoch 10, 70.86%, average loss 26.276075728585788
#  Progress epoch 10, 71.52%, average loss 26.230938884947037
#  Progress epoch 10, 72.19%, average loss 26.307103786993466
#  Progress epoch 10, 72.85%, average loss 26.487386850877243
#  Progress epoch 10, 73.51%, average loss 26.61711344847808
#  Progress epoch 10, 74.17%, average loss 26.67087674992425
#  Progress epoch 10, 74.83%, average loss 26.68761836532998
#  Progress epoch 10, 75.50%, average loss 26.713346188528497
#  Progress epoch 10, 76.16%, average loss 26.716396190809167
#  Progress epoch 10, 76.82%, average loss 26.739871345717333
#  Progress epoch 10, 77.48%, average loss 26.78179841163831
#  Progress epoch 10, 78.15%, average loss 26.802413075657213
#  Progress epoch 10, 78.81%, average loss 26.848161689373626
#  Progress epoch 10, 79.47%, average loss 26.894142762819925
#  Progress epoch 10, 80.13%, average loss 26.91995761808285
#  Progress epoch 10, 80.79%, average loss 26.873788982141214
#  Progress epoch 10, 81.46%, average loss 26.809429874265096
#  Progress epoch 10, 82.12%, average loss 26.773841419527606
#  Progress epoch 10, 82.78%, average loss 26.763238410949707
#  Progress epoch 10, 83.44%, average loss 26.75709363392421
#  Progress epoch 10, 84.11%, average loss 26.736826926704467
#  Progress epoch 10, 84.77%, average loss 26.72327033430338
#  Progress epoch 10, 85.43%, average loss 26.721959158431652
#  Progress epoch 10, 86.09%, average loss 26.705899656735934
#  Progress epoch 10, 86.75%, average loss 26.70580550186507
#  Progress epoch 10, 87.42%, average loss 26.75572677814599
#  Progress epoch 10, 88.08%, average loss 26.76799351828439
#  Progress epoch 10, 88.74%, average loss 26.75444289107821
#  Progress epoch 10, 89.40%, average loss 26.739341135378236
#  Progress epoch 10, 90.07%, average loss 26.73475121750551
#  Progress epoch 10, 90.73%, average loss 26.737792808644095
#  Progress epoch 10, 91.39%, average loss 26.715544057928998
#  Progress epoch 10, 92.05%, average loss 26.67338886535425
#  Progress epoch 10, 92.72%, average loss 26.623466743741716
#  Progress epoch 10, 93.38%, average loss 26.565649269320442
#  Progress epoch 10, 94.04%, average loss 26.511522850520173
#  Progress epoch 10, 94.70%, average loss 26.45646606792103
#  Progress epoch 10, 95.36%, average loss 26.412138428952957
#  Progress epoch 10, 96.03%, average loss 26.375148411454827
#  Progress epoch 10, 96.69%, average loss 26.34323700813398
#  Progress epoch 10, 97.35%, average loss 26.30487484185874
#  Progress epoch 10, 98.01%, average loss 26.27763426626051

# %%
np.load('/home/ai03/Desktop/nas/cj/jupyter/do_bottom/result_2018/brits_i_data.npy')
# Out:
# (2599, 50, 17)
