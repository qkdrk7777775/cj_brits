# %%
import torch 
import numpy as np 
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from sklearn import metrics

# %%
def standardization(X):
    std=np.apply_along_axis(np.nanstd,0,X)
    mean=np.apply_along_axis(np.nanmean,0,X)
    z=(X-mean)/std
    return [z,mean,std]

# %%
class MyDataset(Dataset):
    """ 
    자료 로드 부분 입력
    - forward
      - deltas
      - masks
      - values
    
    - backward
      - deltas
      - masks
      - values
      
    """ 
    def __init__(self):
        super(MyDataset,self).__init__()
        
        df=pd.read_csv('../NA_30per_QC2_gamak1 (1).csv',parse_dates=True,na_values='NaN')
        df['date']=pd.to_datetime(df['date'])

        #full date generate
        df=df.set_index('date')

        #year
        df=df[:'2020-01-01']
        df=df['2019-01-01':]
        temp=standardization(df)
        df=temp[0]
        self.mean_sd=temp[1],temp[2]
        #dt_range = pd.date_range(min(df.index), max(df.index), freq='1H')
        #na_date=set(dt_range)-set(df.index)
        #df=pd.concat([df ,pd.DataFrame(columns=df.columns,index=na_date)],axis=0)
        df=df.sort_index()
        self.df=df
        df_temp=df.copy()
        df_temp=df_temp.fillna(method='ffill')
        self.df_forwards=df_temp
        
        #forward
        dic=dict()
        for var in df.columns.values.tolist():
            print(var)
            temp=list()
            temp.append(0)
            for i in range(1,df.shape[0]):
                temp_df=df[[var]][i:i+1]
                if temp_df.notnull().values!=True:
                    temp.append(i-temp[-1])
                else:
                    temp.append(temp[-1])
            dic.update({var:temp})
        
        self.deltas=np.array(pd.DataFrame(dic))
        #eval generate
        df_temp=df.copy()
        for seed in range(1,df.shape[1]):
            np.random.seed(seed)
            temp_idx=np.random.choice(df.shape[0],int(np.ceil(df.shape[0]*.1)))
            df_temp[df_temp.columns[seed]][temp_idx]=np.nan
        self.eval=df_temp
        
        #backward
        df=df[::-1]
        self.b_df=df
        df_temp=df.copy()
        df_temp=df_temp.fillna(method='ffill')
        self.b_df_forwards=df_temp
        dic=dict()
        for var in df.columns.values.tolist():
            print(var)
            temp=list()
            temp.append(0)
            for i in range(1,df.shape[0]):
                temp_df=df[[var]][i:i+1]
                if temp_df.notnull().values!=True:
                    temp.append(-(i-temp[-1]))
                else:
                    temp.append(temp[-1])
            dic.update({var:temp})
        self.back_deltas=np.array(pd.DataFrame(dic))

        #eval generate
        df_temp=df.copy()
        for seed in range(1,df.shape[1]):
            np.random.seed(seed)
            temp_idx=np.random.choice(df.shape[0],int(np.ceil(df.shape[0]*.1)))
            df_temp[df_temp.columns[seed]][temp_idx]=np.nan
        self.b_eval=df_temp

        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if idx>=50:
            data=dict()
            data['forward']={'values':np.array(self.df)[(idx-50):(idx)],'masks':np.array(self.df.notnull()+0)[(idx-50):(idx)],
                             'deltas':self.deltas[idx:(idx+50)],'forwards':np.array(self.df_forwards)[(idx-50):(idx)],
                             'evals':np.array(self.eval)[(idx-50):(idx)],'eval_masks':np.array(self.eval.notnull()+0)[(idx-50):(idx)]}

            data['backward']={'values':np.array(self.b_df)[(idx-50):(idx)],'masks':np.array(self.b_df.notnull()+0)[(idx-50):(idx)],
                              'deltas':self.back_deltas[(idx-50):(idx)],'forwards':np.array(self.b_df_forwards)[(idx-50):(idx)],
                             'evals':np.array(self.b_eval)[(idx-50):(idx)],'eval_masks':np.array(self.b_eval.notnull()+0)[(idx-50):(idx)]}
            return data

# %%
forward= [Mydata.__getitem__(i) for i in [51,53, 60]]
Mydata.__getitem__(136*32)['forward']['deltas'].tolist()==[]
# Out:
# True

# %%
recs[0]['forward']!=None

# %%
def collate_fn(recs):
    if recs[0]!=None:
        if all(list(map(lambda x: x!=None,recs))):
            forward  = list(map(lambda x: x['forward'], recs))
            backward = list(map(lambda x: x['backward'], recs))
            if all(list(map(lambda x:len(x['deltas'])==50,forward))):
                def to_tensor_dict(recs):
                    values     =torch.FloatTensor(list(map(lambda r:r['values'],recs)))
                    masks      =torch.FloatTensor(list(map(lambda r:r['masks'], recs)))
                    deltas     =torch.FloatTensor(list(map(lambda r:r['deltas'],recs)))
                    evals      =torch.FloatTensor(list(map(lambda r:r['evals'], recs)))
                    eval_masks =torch.FloatTensor(list(map(lambda r:r['eval_masks'], recs)))

                    return {'values':values, 'masks': masks, 'deltas': deltas, 'evals': evals, 'eval_masks': eval_masks} 

                ret_dict = {'forward': to_tensor_dict(forward), 'backward': to_tensor_dict(backward)}
                return ret_dict

# %%
data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=True)
for idx, data in enumerate(data_iter):
    if data!=None:
        data = to_var(data)

# %%
data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=False)
for i,j in enumerate(data_iter):
    j

# %%
Mydata=MyDataset()
# Out:
# depth_top
# depth_middle
# depth_bottom
# wtemp_top
# wtemp_middle
# wtemp_bottom
# sal_top
# sal_middle
# sal_bottom
# do_top
# do_middle
# do_bottom
# density_top
# density_middle
# density_bottom
# dense_diff0
# dense_diff1
# depth_top
# depth_middle
# depth_bottom
# wtemp_top
# wtemp_middle
# wtemp_bottom
# sal_top
# sal_middle
# sal_bottom
# do_top
# do_middle
# do_bottom
# density_top
# density_middle
# density_bottom
# dense_diff0
# dense_diff1

# %%
from torch.autograd import Variable
def to_var(var):
    if torch.is_tensor(var):
        var = Variable(var)
        if torch.cuda.is_available():
            var = var.cuda()
        return var
    if isinstance(var, int) or isinstance(var, float) or isinstance(var, str):
        return var
    if isinstance(var, dict):
        for key in var:
            var[key] = to_var(var[key])
        return var
    if isinstance(var, list):
        var = map(lambda x: to_var(x), var)
        return var

# %%
import os 
#os.chdir('/home/ducj2/data/do_bottom/models')
os.chdir('../')
import models
import utils
import sys
sys.path.append('./models')
from models import brits_i

# %%
data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=False)

# %%
def evaluate(model, val_iter):
    model.eval()

    labels = []
    preds = []

    evals = []
    imputations = []

    save_impute = []
    save_label = []

    for idx, data in enumerate(val_iter):
        if data!=None:
            data = to_var(data)
            ret = model.run_on_batch(data, None)

            # save the imputation results which is used to test the improvement of traditional methods with imputed values
            save_impute.append(ret['imputations'].data.cpu().numpy())

            pred = ret['predictions'].data.cpu().numpy()

            eval_masks = ret['eval_masks'].data.cpu().numpy()
            eval_ = ret['evals'].data.cpu().numpy()
            imputation = ret['imputations'].data.cpu().numpy()

            evals += eval_[np.where(eval_masks == 1)].tolist()
            imputations += imputation[np.where(eval_masks == 1)].tolist()

            # collect test label & prediction
            pred = pred
            preds += pred.tolist()
    preds = np.asarray(preds)
#    print('AUC {}'.format(metrics.roc_auc_score(labels, preds)))

    evals = np.asarray(evals)
    imputations = np.asarray(imputations)

    print('MAE', np.abs(evals - imputations).mean())
    print('MRE', np.abs(evals - imputations).sum() / np.abs(evals).sum())
    save_impute = np.concatenate(save_impute, axis=0)
    np.save('./result_2019/{}_data'.format('brits_i'), save_impute)

# %%
#model = getattr(models, args.model).Model(108, 0.3, 1)
model= brits_i.Model()
if torch.cuda.is_available():
    model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=True)
for epoch in range(1000):
    model.train()
    run_loss = 0.0
    for idx, data in enumerate(data_iter):
        if data!=None:
            data = to_var(data)
            ret = model.run_on_batch(data, optimizer)
            run_loss += ret['loss'].item()
            print('\r Progress epoch {}, {:.2f}%, average loss {}'.format(epoch, (idx + 1) * 100.0 / len(data_iter), run_loss / (idx + 1.0)))
    data_iter=torch.utils.data.DataLoader(Mydata,batch_size=32,collate_fn=collate_fn,shuffle=False)
    evaluate(model, data_iter)
# Out:
#  Progress epoch 0, 28.30%, average loss 5.413096110026042
#  Progress epoch 0, 30.19%, average loss 10.0773024559021
#  Progress epoch 0, 37.74%, average loss 11.897938919067382
#  Progress epoch 0, 56.60%, average loss 10.502836100260417
#  Progress epoch 0, 60.38%, average loss 12.192989826202393
#  Progress epoch 0, 86.79%, average loss 10.170252260954484
#  Progress epoch 0, 100.00%, average loss 10.684904710301813
# MAE 0.5220280459315564
# MRE 0.6913482372503226
#  Progress epoch 1, 5.66%, average loss 42.04443868001302
#  Progress epoch 1, 7.55%, average loss 60.64387512207031
#  Progress epoch 1, 9.43%, average loss 70.93441162109374
#  Progress epoch 1, 11.32%, average loss 76.39178975423177
#  Progress epoch 1, 13.21%, average loss 79.6902335030692
#  Progress epoch 1, 15.09%, average loss 81.45676231384277
#  Progress epoch 1, 16.98%, average loss 82.282716539171
#  Progress epoch 1, 18.87%, average loss 82.26552505493164
#  Progress epoch 1, 20.75%, average loss 80.5570331920277
#  Progress epoch 1, 22.64%, average loss 79.81876373291016
#  Progress epoch 1, 24.53%, average loss 79.78002166748047
#  Progress epoch 1, 26.42%, average loss 79.41245923723493
#  Progress epoch 1, 28.30%, average loss 78.88019612630208
#  Progress epoch 1, 30.19%, average loss 78.06700420379639
#  Progress epoch 1, 32.08%, average loss 76.98687272913315
#  Progress epoch 1, 33.96%, average loss 75.807679494222
#  Progress epoch 1, 35.85%, average loss 75.08823113692434
#  Progress epoch 1, 37.74%, average loss 74.37857799530029
#  Progress epoch 13, 37.74%, average loss 35.2314546585083
#  Progress epoch 13, 39.62%, average loss 35.552342006138396
#  Progress epoch 13, 41.51%, average loss 35.630639336325906
#  Progress epoch 13, 43.40%, average loss 35.49507124527641
#  Progress epoch 13, 45.28%, average loss 35.506377855936684
#  Progress epoch 13, 47.17%, average loss 35.372903442382814
#  Progress epoch 13, 49.06%, average loss 35.01364590571477
#  Progress epoch 13, 50.94%, average loss 34.69786919487847
#  Progress epoch 13, 52.83%, average loss 34.42005171094622
#  Progress epoch 13, 54.72%, average loss 34.25463327868231
#  Progress epoch 13, 56.60%, average loss 34.28845354715983
#  Progress epoch 13, 58.49%, average loss 34.31635985835906
#  Progress epoch 13, 60.38%, average loss 34.28751003742218
#  Progress epoch 13, 62.26%, average loss 34.384478482333094
#  Progress epoch 13, 64.15%, average loss 34.41563146254595
#  Progress epoch 13, 66.04%, average loss 34.297491455078124
#  Progress epoch 13, 67.92%, average loss 34.189190016852486
#  Progress epoch 13, 69.81%, average loss 33.98629322567501
#  Progress epoch 13, 71.70%, average loss 33.964388245030456
#  Progress epoch 13, 73.58%, average loss 33.90134219634227
#  Progress epoch 13, 75.47%, average loss 34.02075409889221
#  Progress epoch 13, 77.36%, average loss 34.174597902995785
#  Progress epoch 13, 79.25%, average loss 34.3785133815947
#  Progress epoch 13, 81.13%, average loss 34.5097756940265
#  Progress epoch 13, 83.02%, average loss 34.69518293033946
#  Progress epoch 13, 84.91%, average loss 35.04594552781847
#  Progress epoch 13, 86.79%, average loss 35.2591378999793
#  Progress epoch 13, 88.68%, average loss 35.49058455609261
#  Progress epoch 13, 90.57%, average loss 35.65393658479055
#  Progress epoch 13, 92.45%, average loss 35.70615562127561
#  Progress epoch 13, 94.34%, average loss 35.85374774932861
# MAE 0.5997266108167307
# MRE 0.7942483903913053
#  Progress epoch 14, 5.66%, average loss 17.08819834391276
#  Progress epoch 14, 7.55%, average loss 25.00961971282959
#  Progress epoch 14, 9.43%, average loss 28.948516845703125
#  Progress epoch 14, 11.32%, average loss 30.767974217732746
#  Progress epoch 14, 13.21%, average loss 31.97156524658203
#  Progress epoch 14, 15.09%, average loss 32.96947002410889
#  Progress epoch 14, 16.98%, average loss 33.522499084472656
#  Progress epoch 14, 18.87%, average loss 34.73818778991699
#  Progress epoch 14, 20.75%, average loss 35.01881096579812
#  Progress epoch 14, 22.64%, average loss 35.394250551859535
#  Progress epoch 14, 24.53%, average loss 35.858279301570015
#  Progress epoch 14, 26.42%, average loss 36.14528438023159
#  Progress epoch 14, 28.30%, average loss 36.13434829711914
#  Progress epoch 14, 30.19%, average loss 35.82110548019409
#  Progress epoch 14, 32.08%, average loss 35.652194528018725
#  Progress epoch 14, 33.96%, average loss 35.35682042439779
#  Progress epoch 14, 35.85%, average loss 35.16159238313374
#  Progress epoch 14, 37.74%, average loss 35.08925552368164
#  Progress epoch 14, 39.62%, average loss 35.24151211693173
#  Progress epoch 14, 41.51%, average loss 35.145952398126774
#  Progress epoch 14, 43.40%, average loss 34.982580682505734
#  Progress epoch 29, 56.60%, average loss 28.486110305786134
#  Progress epoch 29, 58.49%, average loss 28.485566354567005
#  Progress epoch 29, 60.38%, average loss 28.420406341552734
#  Progress epoch 29, 62.26%, average loss 28.434509219545305
#  Progress epoch 29, 64.15%, average loss 28.422880789812872
#  Progress epoch 29, 66.04%, average loss 28.302915900094167
#  Progress epoch 29, 67.92%, average loss 28.196152634090847
#  Progress epoch 29, 69.81%, average loss 28.000540759112383
#  Progress epoch 29, 71.70%, average loss 27.968239332500257
#  Progress epoch 29, 73.58%, average loss 27.866508434980343
#  Progress epoch 29, 75.47%, average loss 27.777836942672728
#  Progress epoch 29, 77.36%, average loss 27.818476467597776
#  Progress epoch 29, 79.25%, average loss 27.907130105154856
#  Progress epoch 29, 81.13%, average loss 27.935041427612305
#  Progress epoch 29, 83.02%, average loss 28.052441987124357
#  Progress epoch 29, 84.91%, average loss 28.30464753044976
#  Progress epoch 29, 86.79%, average loss 28.414952112280805
#  Progress epoch 29, 88.68%, average loss 28.569089727198826
#  Progress epoch 29, 90.57%, average loss 28.6600265900294
#  Progress epoch 29, 92.45%, average loss 28.704190935407365
#  Progress epoch 29, 94.34%, average loss 28.834958648681642
# MAE 0.6130474137438154
# MRE 0.8118898058174918
#  Progress epoch 30, 5.66%, average loss 12.41989262898763
#  Progress epoch 30, 7.55%, average loss 18.96972370147705
#  Progress epoch 30, 9.43%, average loss 22.88094253540039
#  Progress epoch 30, 11.32%, average loss 25.068307876586914
#  Progress epoch 30, 13.21%, average loss 26.831168583461217
#  Progress epoch 30, 15.09%, average loss 28.12792158126831
#  Progress epoch 30, 16.98%, average loss 28.972077263726128
#  Progress epoch 30, 18.87%, average loss 29.961402893066406
#  Progress epoch 30, 20.75%, average loss 29.937910946932707
#  Progress epoch 30, 22.64%, average loss 30.129698117574055
#  Progress epoch 30, 24.53%, average loss 30.19997787475586
#  Progress epoch 30, 26.42%, average loss 30.50127383640834
#  Progress epoch 30, 28.30%, average loss 30.481593322753906
#  Progress epoch 30, 30.19%, average loss 30.13252580165863
#  Progress epoch 30, 32.08%, average loss 29.9080291074865
#  Progress epoch 30, 33.96%, average loss 29.79889244503445
#  Progress epoch 30, 35.85%, average loss 29.85516437731291
#  Progress epoch 30, 37.74%, average loss 29.827750396728515
#  Progress epoch 30, 39.62%, average loss 30.019063313802082
#  Progress epoch 30, 41.51%, average loss 29.9802039753307
#  Progress epoch 30, 43.40%, average loss 29.81070153609566
#  Progress epoch 30, 45.28%, average loss 29.770485003789265
#  Progress epoch 30, 47.17%, average loss 29.621899032592772
#  Progress epoch 30, 49.06%, average loss 29.31130864070012
#  Progress epoch 30, 50.94%, average loss 29.097224906638818
#  Progress epoch 30, 52.83%, average loss 28.897927897317068
#  Progress epoch 30, 54.72%, average loss 28.73006504979627
#  Progress epoch 30, 56.60%, average loss 28.79910882314046
#  Progress epoch 30, 58.49%, average loss 28.858517492971114
#  Progress epoch 30, 60.38%, average loss 28.823812186717987
#  Progress epoch 30, 62.26%, average loss 28.846781528357305
#  Progress epoch 30, 64.15%, average loss 28.842185188742246
#  Progress epoch 30, 66.04%, average loss 28.74028685433524
#  Progress epoch 30, 67.92%, average loss 28.597388373480904
#  Progress epoch 30, 69.81%, average loss 28.385035231306745
#  Progress epoch 30, 71.70%, average loss 28.326095330087764
#  Progress epoch 30, 73.58%, average loss 28.237032376802883
#  Progress epoch 30, 75.47%, average loss 28.221390390396117
#  Progress epoch 30, 77.36%, average loss 28.17684075890518
#  Progress epoch 30, 79.25%, average loss 28.13358552115304
#  Progress epoch 30, 81.13%, average loss 28.074449184329012
#  Progress epoch 30, 83.02%, average loss 28.119765411723744
#  Progress epoch 30, 84.91%, average loss 28.320752758449977
#  Progress epoch 30, 86.79%, average loss 28.407956620921258
#  Progress epoch 30, 88.68%, average loss 28.56858310293644
#  Progress epoch 30, 90.57%, average loss 28.648833632469177
#  Progress epoch 30, 92.45%, average loss 28.68012743580098
#  Progress epoch 30, 94.34%, average loss 28.788357467651366
# MAE 0.6077159267233936
# MRE 0.8048290469517222
#  Progress epoch 31, 5.66%, average loss 13.348836263020834
#  Progress epoch 31, 7.55%, average loss 19.433897972106934
#  Progress epoch 31, 9.43%, average loss 23.421923065185545
#  Progress epoch 31, 11.32%, average loss 25.836859385172527
#  Progress epoch 31, 13.21%, average loss 27.588291713169642
#  Progress epoch 31, 15.09%, average loss 28.641200065612793
#  Progress epoch 31, 16.98%, average loss 29.178909301757812
#  Progress epoch 31, 18.87%, average loss 30.240878677368165
#  Progress epoch 31, 20.75%, average loss 30.304175636985086
#  Progress epoch 31, 22.64%, average loss 30.335541089375813
#  Progress epoch 31, 24.53%, average loss 30.579571357140175
#  Progress epoch 31, 26.42%, average loss 30.626262256077357
#  Progress epoch 31, 28.30%, average loss 30.677667236328126
#  Progress epoch 31, 30.19%, average loss 30.559762239456177
#  Progress epoch 31, 32.08%, average loss 30.376335256239948
#  Progress epoch 31, 33.96%, average loss 30.032153871324326
#  Progress epoch 31, 35.85%, average loss 29.816675085770456
#  Progress epoch 31, 37.74%, average loss 29.701673603057863
#  Progress epoch 31, 39.62%, average loss 29.792310169764928
#  Progress epoch 31, 41.51%, average loss 29.678894823247735
#  Progress epoch 31, 43.40%, average loss 29.5707020137621
#  Progress epoch 31, 45.28%, average loss 29.625744819641113
#  Progress epoch 31, 47.17%, average loss 29.481934127807616
#  Progress epoch 31, 49.06%, average loss 29.167002091040978
#  Progress epoch 31, 50.94%, average loss 28.897088510018808
#  Progress epoch 31, 52.83%, average loss 28.638025215693883
#  Progress epoch 31, 54.72%, average loss 28.47140253001246
#  Progress epoch 31, 56.60%, average loss 28.507465108235678
#  Progress epoch 31, 58.49%, average loss 28.573263906663463
#  Progress epoch 31, 60.38%, average loss 28.590515911579132
#  Progress epoch 31, 62.26%, average loss 28.6759766665372
#  Progress epoch 31, 64.15%, average loss 28.701449113733627
#  Progress epoch 31, 66.04%, average loss 28.606695774623326
#  Progress epoch 31, 67.92%, average loss 28.518490314483643
#  Progress epoch 31, 69.81%, average loss 28.342598889325117
